# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/films.csv")

# %%
from tokenizer.tokenizer import Tokenizer

tk = Tokenizer()

pathen = "tokenizer/tokens_encode.json"
pathde = "tokenizer/tokens_decode.json"

res = tk.encode("hello : – my friendOOO", pathen)
tk.decode(res, pathde)
# Out:
# 'hello :  my friendooo'

# %%
import ast

df2 = pd.read_csv("data/films_tokenized.csv")

# df2['name'] = df2['name'].apply(lambda x: tk.encode(x, pathen))
# df2['country'] = df2['country'].apply(lambda x: tk.encode(x, pathen))
# df2['genre'] = df2['genre'].apply(lambda x: tk.encode(x, pathen))
# df2['director'] = df2['director'].apply(lambda x: tk.encode(x, pathen))
# df2['cast'] = df2['cast'].apply(lambda x: tk.encode(x, pathen))
# df2['description'] = df2['description'].apply(lambda x: tk.encode(x, pathen))

df2['country'] = df2['country'].apply(lambda x: tk.decode(np.array(ast.literal_eval(x)), pathde))
df2['name'] = df2['name'].apply(lambda x: tk.decode(np.array(ast.literal_eval(x)), pathde))
df2['cast'] = df2['cast'].apply(lambda x: tk.decode(np.array(ast.literal_eval(x)), pathde))
df2['description'] = df2['description'].apply(lambda x: tk.decode(np.array(ast.literal_eval(x)), pathde))

df2.head(10)

# np.array(ast.literal_eval(df2['country'][0]))
# Out:
#    film_id                          name  year  \
# 0        0                       моана 2  2024
# 1        1     приключения паддингтона 3  2024
# 2        2               миссия: красный  2024
# 3        3  злая: сказка о ведьме запада  2024
# 4        4             дюна: пророчество  2024
# 5        5          тогда. сейчас. потом  2024
# 6        6        веном: последний танец  2024
# 7        7                      истерия!  2024
# 8        8                   гладиатор 2  2024
# 9        9                      дорогуша  2024
#
#                                 country  \
# 0                           канада, сша
# 1  сша, великобритания, франция, япония
# 2                                   сша
# 3                                   сша
# 4                                   сша
# 5                                   сша
# 6          сша, великобритания, мексика
# 7                                   сша
# 8                   сша, великобритания
# 9                        великобритания
#
#                                                genre  duration  \
# 0  [4184, 4392, 3415, 6530, 11921, 6357, 3962, 43...     100.0
# 1  [4184, 4392, 3415, 6530, 11924, 4832, 4181, 63...     106.0
# 2  [4184, 4392, 3415, 6530, 11909, 4610, 3197, 42...     123.0
# 3  [3094, 3517, 3962, 10900, 4392, 4293, 3423, 29...     160.0
# 4  [3094, 3517, 3962, 10900, 3423, 2983, 3042, 11...      45.0
# 5                                   [3423, 2983, 27]     104.0
# 6  [5058, 3963, 4283, 4895, 11909, 4610, 3197, 42...     110.0
# 7        [5058, 3963, 4283, 4895, 11928, 3733, 4960]      45.0
# 8  [3423, 2983, 3042, 11909, 4610, 3197, 4241, 11...     148.0
# 9        [3423, 2983, 3042, 11919, 4618, 3519, 3983]      45.0
#
#                                             director  \
# 0  [3436, 3197, 3488, 3411, 4840, 3962, 11921, 4348]
# 1               [3406, 3297, 4360, 5159, 4296, 4619]
# 2               [3413, 3525, 4251, 4199, 3846, 2984]
# 3                   [3413, 4619, 11921, 10682, 5606]
# 4              [3413, 4619, 11919, 2983, 3532, 4619]
# 5        [4838, 3084, 4842, 11916, 3528, 3526, 3969]
# 6               [4174, 4290, 4033, 4387, 4841, 3527]
# 7    [2982, 4619, 4947, 11908, 4307, 3188, 4828, 45]
# 8                 [4832, 3418, 4033, 4943, 4624, 46]
# 9                    [6252, 4278, 11912, 3748, 4514]
#
#                                                 cast  \
# 0  рэйчел хаус, халиси ламберт-цуда, setarosa tui...
# 1  бен миллер, эмма сиди, хью бонневилль, карла т...
# 2  коуди истербрук, james cheek, дж.к. симмонс, м...
# 3  vicki noon, жарлан боголюбов, шэрон д. кларк, ...
# 4  люси расселл, камилла бипут, флора монтгомери,...
# 5  робин райт, том хэнкс, джоэл улетт, albie salt...
# 6  чиветель эджиофор, джаред абрахамсон, стивен г...
# 7  брэндон батлер, джессика луза, sydou maiga, ma...
# 8  элфи темпест, пол кэнделент, джозеф куинн, адр...
# 9  александра доулинг, нитин ганатра, кэлам линч,...
#
#                                          description
# 0  моане предстоит долгий путь в неизведанные зем...
# 1  став любимым пушистым домочадцем и законным бр...
# 2  любимый праздник детства  рождество под угрозо...
# 3  в стране жевунов с жизнерадостной и игривой же...
# 4  бене гессерит стремятся контролировать важнейш...
# 5  новая англия, самый обычный, ничем не приметны...
# 6  насколько тяжело сочетать в себе две сущности,...
# 7  события происходят в америке 80-х годов, когда...
# 8  власть, интриги, коварство - всё это неотъемле...
# 9  рианнон льюис скромная и ничем не примечательн...
