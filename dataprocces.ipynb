# %%
import numpy as np
import pandas as pd

# %%
data_frame = pd.read_csv("films.csv")
data_frame
# Out:
#                               name    year  \
# 0                          Моана 2  2024.0
# 1        Приключения Паддингтона 3  2024.0
# 2                  Миссия: Красный  2024.0
# 3     Злая: Сказка о ведьме Запада  2024.0
# 4                Дюна: Пророчество  2024.0
# ...                            ...     ...
# 1282                       Зеркала  2008.0
# 1283                    Сделай шаг  2008.0
# 1284                  Берлин зовет  2008.0
# 1285                  Дороти Миллс  2008.0
# 1286                      Наруто 5  2008.0
#
#                                    country  \
# 0                              Канада, США
# 1     США, Великобритания, Франция, Япония
# 2                                      США
# 3                                      США
# 4                                      США
# ...                                    ...
# 1282       США, Франция, Германия, Румыния
# 1283                                   США
# 1284                              Германия
# ...

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1287 entries, 0 to 1286
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1287 non-null   object
#  1   year         1286 non-null   float64
#  2   country      1286 non-null   object
#  3   genre        1286 non-null   object
#  4   duration     1183 non-null   float64
#  5   director     1277 non-null   object
#  6   cast         1275 non-null   object
#  7   description  1286 non-null   object
# dtypes: float64(2), object(6)
# memory usage: 80.6+ KB

# %%
rows_with_missing_values = data_frame[data_frame.isna().any(axis=1)]

pd.set_option('display.max_rows', None)  # Показывать все строки
pd.set_option('display.max_columns', None)  # Показывать все столбцы
pd.set_option('display.width', None)  # Автоматическая ширина
pd.set_option('display.max_colwidth', None)  # Не ограничивать длину столбцов

rows_with_missing_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 110 entries, 4 to 899
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         110 non-null    object
#  1   year         109 non-null    float64
#  2   country      109 non-null    object
#  3   genre        109 non-null    object
#  4   duration     6 non-null      float64
#  5   director     100 non-null    object
#  6   cast         98 non-null     object
#  7   description  109 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 7.7+ KB
